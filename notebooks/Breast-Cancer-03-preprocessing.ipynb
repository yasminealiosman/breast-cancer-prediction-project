# %% [markdown]
# # Feature Engineering + Multicollinearity Check

# %% [markdown]
# This notebook prepares the dataset for modeling by:
#
# - **Feature engineering**
#   Creating new derived features (ratios, squared terms, interactions, and normalized measures) to capture nonlinear relationships and improve predictive power.
#
# - **Scaling features for consistency**
#   Ensures all predictors are on the same scale, which is important for models sensitive to feature magnitude.
#
# - **Checking multicollinearity using Variance Inflation Factor (VIF)**
#   Identifies redundant predictors that are highly correlated with each other, which can destabilize linear models.
#
# - **Pruning redundant features**
#   Removes or consolidates features with excessive collinearity while preserving clinically meaningful predictors, improving model stability and interpretability.

# %% [markdown]
# ##Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ###Import libaries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %% [markdown]
# ###Load Dataset

# %%
data_path = "/content/drive/My Drive/Portfolio/DataSciencePortfolio/Projects/Breast-Cancer/data/raw/Breast_cancer_dataset.csv"
df = pd.read_csv(data_path)


#Encode diagnosis
df["diagnosis"] = df["diagnosis"].map({"M": 1, "B": 0})


# Drop irrelevant columns
df.drop(columns=["id", "Unnamed: 32"], errors="ignore", inplace=True)

# Check result
df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 2         0.2069  ...         23.57          25.53           152.50
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Variance Inflation Factor (VIF)
# Compute VIF to detect multicollinearity among features.
#
# Very high VIF (>10) indicates redundancy. We will prune features iteratively while protecting clinically meaningful predictors.

# %%
def calculate_vif(df_input):
    features_df = df_input.copy()

    if "diagnosis" in features_df.columns:
        features_df = features_df.drop(columns=["diagnosis"])

    # Handle case where no features are left after dropping 'diagnosis'
    if features_df.empty:
        print("No features to calculate VIF for after dropping 'diagnosis'.")
        return pd.DataFrame(columns=["feature", "VIF"])

    vif_data = pd.DataFrame()
    vif_data["feature"] = features_df.columns # Assign feature names
    vif_data["VIF"] = [
        variance_inflation_factor(features_df.values, i) # Calculate VIF only for features
        for i in range(features_df.shape[1])
    ]
    return vif_data.sort_values(by="VIF", ascending=False)

vif_results = calculate_vif(df)
print("Initial VIF calculated.")
print(vif_results)
# Out:
# Initial VIF calculated.
#                     feature           VIF
# 0               radius_mean  63306.172036
# 2            perimeter_mean  58123.586079
# 20             radius_worst   9674.742602
# 22          perimeter_worst   4487.781270
# 3                 area_mean   1287.262339
# 23               area_worst   1138.759252
# 9    fractal_dimension_mean    629.679874
# 29  fractal_dimension_worst    423.396723
# 4           smoothness_mean    393.398166
# 24         smoothness_worst    375.597155
# 21            texture_worst    343.004387
# 1              texture_mean    251.047108
# 10                radius_se    236.665738
# 28           symmetry_worst    218.919805
# 12             perimeter_se    211.396334
# 5          compactness_mean    200.980354
# 8             symmetry_mean    184.426558
# 6            concavity_mean    157.855046
# 7       concave points_mean    154.241268
# 27     concave points_worst    148.673180
# 25        compactness_worst    132.884276
# 26          concavity_worst     86.310362
# 13                  area_se     72.466468
# 17        concave points_se     53.698656
# 15           compactness_se     44.919651
# 18              symmetry_se     37.176452
# 16             concavity_se     33.244099
# 19     fractal_dimension_se     27.532631
# 14            smoothness_se     26.170243
# 11               texture_se     24.675367

# %% [markdown]
# ## Feature Engineering
#
#
# Feature engineering creates new predictors from existing ones to capture more complex relationships and reduce redundancy.
#
# **Purpose:**
# Feature engineering consolidates redundant raw predictors into more stable, interpretable features.
# This step ensures that when we later prune with VIF, we retain predictive signal in engineered form while reducing collinearity.
#
# In this notebook, we apply several transformations:
#
# - **Ratios**
#   Combine related features to highlight proportional relationships (e.g., `perimeter_radius_ratio`, `concave_perimeter_ratio`).
#   These consolidate overlapping predictors into interpretable measures of tumor irregularity relative to size.
#
# - **Squared terms**
#   Add polynomial features (e.g., `area_worst_squared`, `concavity_mean_squared`) to capture non-linear effects.
#   These help the model detect curved or extreme patterns in tumor size and concavity.
#
# - **Normalized features**
#   Scale features relative to others (e.g., `normalized_texture`, `normalized_symmetry`).
#   These emphasize variation across tumors rather than absolute values.
#
# - **Interaction terms**
#   Combine features to reflect clinically meaningful interactions (e.g., `concavity_compactness_ratio`, `symmetry_fractal_ratio`).
# These highlight how shape descriptors interact to influence malignancy risk.

# %% [markdown]
# ###Seperate Features and Target

# %%
X = df.drop(columns=['diagnosis'])
y = df['diagnosis']

# %% [markdown]
# ###Ratios / Proportions

# %%
X['perimeter_radius_ratio'] = X['perimeter_mean'] / X['radius_mean']
X['concavity_compactness_ratio'] = X['concavity_mean'] / X['compactness_mean']
X['concave_perimeter_ratio'] = X['concave points_worst'] / X['perimeter_worst']
X['symmetry_fractal_ratio'] = X['symmetry_mean'] / X['fractal_dimension_mean']

# %% [markdown]
# ###Polynomial Terms

# %%
#Size Feature
X['radius_mean_squared'] = X['radius_mean'] ** 2
X['area_worst_squared'] = X['area_worst'] ** 2

#Concavity / Compactness
X['concavity_mean_squared'] = X['concavity_mean'] ** 2

# %% [markdown]
# ###Interaction Terms

# %%
#Concavity x Compactness
X['concavity_compactness_interaction'] = X['concavity_mean'] * X['compactness_mean']

#Smoothness x Symmetry
X['smoothness_symmetry_interaction'] = X['smoothness_mean'] * X['symmetry_mean']

# %% [markdown]
# ###Domain‑Informed Transformations

# %%
#Log Transforms
X['log_area_worst'] = np.log1p(X['area_worst'])
X['log_perimeter_mean'] = np.log1p(X['perimeter_mean'])

#Normalization by Tumor Size
X['normalized_texture'] = X['texture_mean'] / X['radius_mean']
X['normalized_symmetry'] = X['symmetry_mean'] / X['radius_mean']

# %% [markdown]
# ###Verify All Engineered Features
# Preview new columns and check for NaN, Inf and Correlations.

# %%
engineered_cols = [
    # Ratios
    'perimeter_radius_ratio','concavity_compactness_ratio',
    'concave_perimeter_ratio','symmetry_fractal_ratio',
    # Polynomial
    'area_worst_squared','concavity_mean_squared',
    # Interaction
    'concavity_compactness_interaction','smoothness_symmetry_interaction',
    # Log/Normalization
    'log_area_worst','log_perimeter_mean','normalized_texture','normalized_symmetry'
]

# Preview first 5 rows
print("Preview of engineered features:")
print(X[engineered_cols].head(), "\n")

# Check for NaN values
print("NaN counts:")
print(X[engineered_cols].isna().sum(), "\n")

# Check for Inf values
print("Inf counts:")
print(np.isinf(X[engineered_cols]).sum(), "\n")

# Correlation with originals
print("Correlation with base features:")
print(X[['radius_mean','area_worst','concavity_mean','compactness_mean',
         'texture_mean','smoothness_mean','symmetry_mean','fractal_dimension_mean'] + engineered_cols].corr())
# Out:
# Preview of engineered features:
#    perimeter_radius_ratio  concavity_compactness_ratio  \
# 0                6.826014                     1.081052
# 1                6.460865                     1.105036
# 2                6.602336                     1.234522
# 3                6.793345                     0.850299
# 4                6.658452                     1.490964
#
#    concave_perimeter_ratio  symmetry_fractal_ratio  area_worst_squared  \
# 0                 0.001438                3.073307          4076361.00
# 1                 0.001171                3.197459          3825936.00
# 2                 0.001593                3.448908          2920681.00
# 3                 0.002604                2.665230           322283.29
# 4                 0.001068                3.074962          2480625.00
#
#    concavity_mean_squared  concavity_compactness_interaction  \
# 0                0.090060                           0.083308
# 1                0.007552                           0.006834
# 2                0.038967                           0.031564
# 3                0.058274                           0.068533
# 4                0.039204                           0.026294
#
#    smoothness_symmetry_interaction  log_area_worst  log_perimeter_mean  \
# 0                         0.028641        7.610853            4.818667
# 1                         0.015355        7.579168            4.897093
# 2                         0.022676        7.444249            4.875197
# 3                         0.037007        6.343353            4.364117
# 4                         0.018144        7.362645            4.913390
#
#    normalized_texture  normalized_symmetry
# 0            0.576987             0.013446
# 1            0.863879             0.008809
# 2            1.079228             0.010508
# 3            1.784588             0.022741
# 4            0.706752             0.008916
#
# NaN counts:
# perimeter_radius_ratio               0
# concavity_compactness_ratio          0
# concave_perimeter_ratio              0
# symmetry_fractal_ratio               0
# area_worst_squared                   0
# concavity_mean_squared               0
# concavity_compactness_interaction    0
# smoothness_symmetry_interaction      0
# log_area_worst                       0
# log_perimeter_mean                   0
# normalized_texture                   0
# normalized_symmetry                  0
# dtype: int64
#
# Inf counts:
# perimeter_radius_ratio               0
# concavity_compactness_ratio          0
# concave_perimeter_ratio              0
# symmetry_fractal_ratio               0
# area_worst_squared                   0
# concavity_mean_squared               0
# concavity_compactness_interaction    0
# smoothness_symmetry_interaction      0
# log_area_worst                       0
# log_perimeter_mean                   0
# normalized_texture                   0
# normalized_symmetry                  0
# dtype: int64
#
# Correlation with base features:
#                                    radius_mean  area_worst  concavity_mean  \
# radius_mean                           1.000000    0.941082        0.676764
# area_worst                            0.941082    1.000000        0.675987
# concavity_mean                        0.676764    0.675987        1.000000
# compactness_mean                      0.506124    0.509604        0.883121
# texture_mean                          0.323782    0.343546        0.302418
# smoothness_mean                       0.170581    0.206718        0.521984
# symmetry_mean                         0.147741    0.177193        0.500667
# fractal_dimension_mean               -0.311631   -0.231854        0.336783
# perimeter_radius_ratio                0.615185    0.586011        0.896460
# concavity_compactness_ratio           0.696277    0.678647        0.853861
# concave_perimeter_ratio               0.321932    0.306881        0.681657
# symmetry_fractal_ratio                0.411132    0.382251        0.275143
# area_worst_squared                    0.819321    0.945472        0.599152
# concavity_mean_squared                0.586521    0.592497        0.931148
# concavity_compactness_interaction     0.575249    0.577236        0.940227
# smoothness_symmetry_interaction       0.179043    0.214189        0.585755
# log_area_worst                        0.966599    0.943851        0.661225
# log_perimeter_mean                    0.986584    0.905311        0.682496
# normalized_texture                   -0.573940   -0.480665       -0.293965
# normalized_symmetry                  -0.757079   -0.647493       -0.260271
#
#                                    compactness_mean  texture_mean  \
# radius_mean                                0.506124      0.323782
# area_worst                                 0.509604      0.343546
# concavity_mean                             0.883121      0.302418
# compactness_mean                           1.000000      0.236702
# texture_mean                               0.236702      1.000000
# smoothness_mean                            0.659123     -0.023389
# symmetry_mean                              0.602641      0.071401
# fractal_dimension_mean                     0.565369     -0.076437
# perimeter_radius_ratio                     0.948717      0.267880
# concavity_compactness_ratio                0.602314      0.296706
# concave_perimeter_ratio                    0.722757      0.129470
# symmetry_fractal_ratio                     0.201481      0.137439
# area_worst_squared                         0.433088      0.296802
# concavity_mean_squared                     0.787299      0.244793
# concavity_compactness_interaction          0.902736      0.260552
# smoothness_symmetry_interaction            0.722564      0.026464
# log_area_worst                             0.513791      0.347764
# log_perimeter_mean                         0.538491      0.322669
# normalized_texture                        -0.225043      0.542725
# normalized_symmetry                       -0.083767     -0.227471
#
#                                    smoothness_mean  symmetry_mean  \
# radius_mean                               0.170581       0.147741
# area_worst                                0.206718       0.177193
# concavity_mean                            0.521984       0.500667
# compactness_mean                          0.659123       0.602641
# texture_mean                             -0.023389       0.071401
# smoothness_mean                           1.000000       0.557775
# symmetry_mean                             0.557775       1.000000
# fractal_dimension_mean                    0.584792       0.479921
# perimeter_radius_ratio                    0.562923       0.509091
# concavity_compactness_ratio               0.328191       0.281831
# concave_perimeter_ratio                   0.552795       0.431320
# symmetry_fractal_ratio                    0.137325       0.708857
# area_worst_squared                        0.184067       0.147671
# concavity_mean_squared                    0.463257       0.481757
# concavity_compactness_interaction         0.524973       0.546271
# smoothness_symmetry_interaction           0.874301       0.882029
# log_area_worst                            0.188693       0.161543
# log_perimeter_mean                        0.188234       0.161561
# normalized_texture                       -0.156890      -0.044230
# normalized_symmetry                       0.191863       0.464963
#
#                                    fractal_dimension_mean  \
# radius_mean                                     -0.311631
# area_worst                                      -0.231854
# concavity_mean                                   0.336783
# compactness_mean                                 0.565369
# texture_mean                                    -0.076437
# smoothness_mean                                  0.584792
# symmetry_mean                                    0.479921
# fractal_dimension_mean                           1.000000
# perimeter_radius_ratio                           0.403300
# concavity_compactness_ratio                      0.049004
# concave_perimeter_ratio                          0.421054
# symmetry_fractal_ratio                          -0.269586
# area_worst_squared                              -0.177928
# concavity_mean_squared                           0.329260
# concavity_compactness_interaction                0.421714
# smoothness_symmetry_interaction                  0.610463
# log_area_worst                                  -0.300462
# log_perimeter_mean                              -0.296569
# normalized_texture                               0.234906
# normalized_symmetry                              0.590179
#
#                                    perimeter_radius_ratio  \
# radius_mean                                      0.615185
# area_worst                                       0.586011
# concavity_mean                                   0.896460
# compactness_mean                                 0.948717
# texture_mean                                     0.267880
# smoothness_mean                                  0.562923
# symmetry_mean                                    0.509091
# fractal_dimension_mean                           0.403300
# perimeter_radius_ratio                           1.000000
# concavity_compactness_ratio                      0.690375
# concave_perimeter_ratio                          0.712410
# symmetry_fractal_ratio                           0.228785
# area_worst_squared                               0.482015
# concavity_mean_squared                           0.777928
# concavity_compactness_interaction                0.876020
# smoothness_symmetry_interaction                  0.611952
# log_area_worst                                   0.628272
# log_perimeter_mean                               0.663510
# normalized_texture                              -0.323525
# normalized_symmetry                             -0.259856
#
#                                    concavity_compactness_ratio  \
# radius_mean                                           0.696277
# area_worst                                            0.678647
# concavity_mean                                        0.853861
# compactness_mean                                      0.602314
# texture_mean                                          0.296706
# smoothness_mean                                       0.328191
# symmetry_mean                                         0.281831
# fractal_dimension_mean                                0.049004
# perimeter_radius_ratio                                0.690375
# concavity_compactness_ratio                           1.000000
# concave_perimeter_ratio                               0.646045
# symmetry_fractal_ratio                                0.281519
# area_worst_squared                                    0.579565
# concavity_mean_squared                                0.700348
# concavity_compactness_interaction                     0.653702
# smoothness_symmetry_interaction                       0.337176
# log_area_worst                                        0.693094
# log_perimeter_mean                                    0.699906
# normalized_texture                                   -0.332668
# normalized_symmetry                                  -0.400983
#
#                                    concave_perimeter_ratio  \
# radius_mean                                       0.321932
# area_worst                                        0.306881
# concavity_mean                                    0.681657
# compactness_mean                                  0.722757
# texture_mean                                      0.129470
# smoothness_mean                                   0.552795
# symmetry_mean                                     0.431320
# fractal_dimension_mean                            0.421054
# perimeter_radius_ratio                            0.712410
# concavity_compactness_ratio                       0.646045
# concave_perimeter_ratio                           1.000000
# symmetry_fractal_ratio                            0.137663
# area_worst_squared                                0.207726
# concavity_mean_squared                            0.505429
# concavity_compactness_interaction                 0.583614
# smoothness_symmetry_interaction                   0.550509
# log_area_worst                                    0.380674
# log_perimeter_mean                                0.381716
# normalized_texture                               -0.206705
# normalized_symmetry                              -0.065861
#
#                                    symmetry_fractal_ratio  area_worst_squared  \
# radius_mean                                      0.411132            0.819321
# area_worst                                       0.382251            0.945472
# concavity_mean                                   0.275143            0.599152
# compactness_mean                                 0.201481            0.433088
# texture_mean                                     0.137439            0.296802
# smoothness_mean                                  0.137325            0.184067
# symmetry_mean                                    0.708857            0.147671
# fractal_dimension_mean                          -0.269586           -0.177928
# perimeter_radius_ratio                           0.228785            0.482015
# concavity_compactness_ratio                      0.281519            0.579565
# concave_perimeter_ratio                          0.137663            0.207726
# symmetry_fractal_ratio                           1.000000            0.310711
# area_worst_squared                               0.310711            1.000000
# concavity_mean_squared                           0.251674            0.565493
# concavity_compactness_interaction                0.245588            0.523921
# smoothness_symmetry_interaction                  0.468779            0.184055
# log_area_worst                                   0.413430            0.798676
# log_perimeter_mean                               0.410689            0.753839
# normalized_texture                              -0.234665           -0.381285
# normalized_symmetry                              0.043472           -0.513663
#
#                                    concavity_mean_squared  \
# radius_mean                                      0.586521
# area_worst                                       0.592497
# concavity_mean                                   0.931148
# compactness_mean                                 0.787299
# texture_mean                                     0.244793
# smoothness_mean                                  0.463257
# symmetry_mean                                    0.481757
# fractal_dimension_mean                           0.329260
# perimeter_radius_ratio                           0.777928
# concavity_compactness_ratio                      0.700348
# concave_perimeter_ratio                          0.505429
# symmetry_fractal_ratio                           0.251674
# area_worst_squared                               0.565493
# concavity_mean_squared                           1.000000
# concavity_compactness_interaction                0.957849
# smoothness_symmetry_interaction                  0.554368
# log_area_worst                                   0.539277
# log_perimeter_mean                               0.571047
# normalized_texture                              -0.242296
# normalized_symmetry                             -0.179766
#
#                                    concavity_compactness_interaction  \
# radius_mean                                                 0.575249
# area_worst                                                  0.577236
# concavity_mean                                              0.940227
# compactness_mean                                            0.902736
# texture_mean                                                0.260552
# smoothness_mean                                             0.524973
# symmetry_mean                                               0.546271
# fractal_dimension_mean                                      0.421714
# perimeter_radius_ratio                                      0.876020
# concavity_compactness_ratio                                 0.653702
# concave_perimeter_ratio                                     0.583614
# symmetry_fractal_ratio                                      0.245588
# area_worst_squared                                          0.523921
# concavity_mean_squared                                      0.957849
# concavity_compactness_interaction                           1.000000
# smoothness_symmetry_interaction                             0.627960
# log_area_worst                                              0.550153
# log_perimeter_mean                                          0.580864
# normalized_texture                                         -0.238049
# normalized_symmetry                                        -0.160226
#
#                                    smoothness_symmetry_interaction  \
# radius_mean                                               0.179043
# area_worst                                                0.214189
# concavity_mean                                            0.585755
# compactness_mean                                          0.722564
# texture_mean                                              0.026464
# smoothness_mean                                           0.874301
# symmetry_mean                                             0.882029
# fractal_dimension_mean                                    0.610463
# perimeter_radius_ratio                                    0.611952
# concavity_compactness_ratio                               0.337176
# concave_perimeter_ratio                                   0.550509
# symmetry_fractal_ratio                                    0.468779
# area_worst_squared                                        0.184055
# concavity_mean_squared                                    0.554368
# concavity_compactness_interaction                         0.627960
# smoothness_symmetry_interaction                           1.000000
# log_area_worst                                            0.196801
# log_perimeter_mean                                        0.198024
# normalized_texture                                       -0.113609
# normalized_symmetry                                       0.368361
#
#                                    log_area_worst  log_perimeter_mean  \
# radius_mean                              0.966599            0.986584
# area_worst                               0.943851            0.905311
# concavity_mean                           0.661225            0.682496
# compactness_mean                         0.513791            0.538491
# texture_mean                             0.347764            0.322669
# smoothness_mean                          0.188693            0.188234
# symmetry_mean                            0.161543            0.161561
# fractal_dimension_mean                  -0.300462           -0.296569
# perimeter_radius_ratio                   0.628272            0.663510
# concavity_compactness_ratio              0.693094            0.699906
# concave_perimeter_ratio                  0.380674            0.381716
# symmetry_fractal_ratio                   0.413430            0.410689
# area_worst_squared                       0.798676            0.753839
# concavity_mean_squared                   0.539277            0.571047
# concavity_compactness_interaction        0.550153            0.580864
# smoothness_symmetry_interaction          0.196801            0.198024
# log_area_worst                           1.000000            0.976047
# log_perimeter_mean                       0.976047            1.000000
# normalized_texture                      -0.555965           -0.596890
# normalized_symmetry                     -0.754381           -0.778750
#
#                                    normalized_texture  normalized_symmetry
# radius_mean                                 -0.573940            -0.757079
# area_worst                                  -0.480665            -0.647493
# concavity_mean                              -0.293965            -0.260271
# compactness_mean                            -0.225043            -0.083767
# texture_mean                                 0.542725            -0.227471
# smoothness_mean                             -0.156890             0.191863
# symmetry_mean                               -0.044230             0.464963
# fractal_dimension_mean                       0.234906             0.590179
# perimeter_radius_ratio                      -0.323525            -0.259856
# concavity_compactness_ratio                 -0.332668            -0.400983
# concave_perimeter_ratio                     -0.206705            -0.065861
# symmetry_fractal_ratio                      -0.234665             0.043472
# area_worst_squared                          -0.381285            -0.513663
# concavity_mean_squared                      -0.242296            -0.179766
# concavity_compactness_interaction           -0.238049            -0.160226
# smoothness_symmetry_interaction             -0.113609             0.368361
# log_area_worst                              -0.555965            -0.754381
# log_perimeter_mean                          -0.596890            -0.778750
# normalized_texture                           1.000000             0.517248
# normalized_symmetry                          0.517248             1.000000

# %% [markdown]
# ## VIF Pruning
# We iteratively drop features with VIF above 10, except for protected predictors (`concave points_worst`, `area_worst`, `concavity_mean`, etc.) to get a reduced feature set with manageable collinearity.
# This balances predictive strength with statistical stability.

# %%
def vif_prune(df, threshold=10.0, protected_features=None):
    """
    Iteratively drop features with VIF above threshold until all non-protected are stable.
    Protected features are kept regardless of VIF.
    """
    if protected_features is None:
        protected_features = []

    while True:
        vif_data = calculate_vif(df)

        # Filter out protected features
        non_protected = vif_data[~vif_data["feature"].isin(protected_features)]
        max_vif = non_protected["VIF"].max()

        if max_vif > threshold:
            drop_feature = non_protected.loc[non_protected["VIF"].idxmax(), "feature"]
            print(f"Dropping '{drop_feature}' with VIF={max_vif:.2f}")
            df = df.drop(columns=[drop_feature])
        else:
            print("VIF pruning complete. All non-protected features below threshold.")
            return df, vif_data

# Instantiate StandardScaler
scaler = StandardScaler()

# Scale the features
X_scaled = scaler.fit_transform(X)
X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns)

# Define the highly predictive features you want to protect
protected = [
    "concave points_worst",
    "area_worst",
    "concavity_mean",
    "radius_worst",
    "perimeter_worst"
]

# Run pruning but keep protected features
X_pruned_df, vif_final = vif_prune(X_scaled_df, threshold=10.0, protected_features=protected)

print("Final VIF results:")
print(vif_final)
# Out:
# Dropping 'radius_mean' with VIF=35605.16
# Dropping 'area_mean' with VIF=6885.08
# Dropping 'perimeter_mean' with VIF=5220.10
# Dropping 'log_perimeter_mean' with VIF=505.37
# Dropping 'log_area_worst' with VIF=357.04
# Dropping 'symmetry_mean' with VIF=257.44
# Dropping 'concavity_compactness_interaction' with VIF=100.74
# Dropping 'smoothness_symmetry_interaction' with VIF=83.54
# Dropping 'area_worst_squared' with VIF=79.28
# Dropping 'radius_se' with VIF=74.67
# Dropping 'compactness_mean' with VIF=71.39
# Dropping 'concave points_mean' with VIF=63.13
# Dropping 'concave_perimeter_ratio' with VIF=38.85
# Dropping 'normalized_symmetry' with VIF=36.97
# Dropping 'concavity_mean_squared' with VIF=32.96
# Dropping 'perimeter_se' with VIF=32.04
# Dropping 'concavity_worst' with VIF=30.61
# Dropping 'texture_mean' with VIF=26.06
# Dropping 'compactness_worst' with VIF=25.40
# Dropping 'radius_mean_squared' with VIF=22.76
# Dropping 'perimeter_radius_ratio' with VIF=15.41
# Dropping 'fractal_dimension_mean' with VIF=11.01
# VIF pruning complete. All non-protected features below threshold.
# Final VIF results:
#                         feature         VIF
# 10                 radius_worst  189.367100
# 12              perimeter_worst  156.128650
# 13                   area_worst   63.272066
# 15         concave points_worst   21.971077
# 1                concavity_mean   18.026539
# 14             smoothness_worst    9.703848
# 11                texture_worst    9.396770
# 6                  concavity_se    8.770633
# 20           normalized_texture    8.150244
# 7             concave points_se    8.124062
# 16               symmetry_worst    7.842924
# 17      fractal_dimension_worst    7.767974
# 18  concavity_compactness_ratio    7.399523
# 5                compactness_se    6.988708
# 9          fractal_dimension_se    6.062277
# 0               smoothness_mean    5.671551
# 3                       area_se    5.107936
# 8                   symmetry_se    4.645492
# 4                 smoothness_se    3.796319
# 2                    texture_se    3.175825
# 19       symmetry_fractal_ratio    2.722394

# %% [markdown]
# ##Save Pruned Data

# %%
import os

# Define the full path for the file
file_path = "/content/drive/My Drive/Portfolio/DataSciencePortfolio/Projects/Breast-Cancer/data/preprocessed/breast_cancer_pruned.csv"

# Extract the directory path from the file path
directory_path = os.path.dirname(file_path)

# Create the directory if it does not exist
os.makedirs(directory_path, exist_ok=True)

X_pruned_df["diagnosis"] = y
X_pruned_df.to_csv(file_path, index=False)
