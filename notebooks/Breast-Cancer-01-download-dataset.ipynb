# %% [markdown]
# # Download & Save Kaggle Dataset to Project Folder

# %% [markdown]
# ## Introduction
# **Goals**
#
#
#
#
#
#
# *   Download the Dataset.
#
#
# * Save it to a structured folder in Google Drive.
#
#
#
#
#
#
#
#
#
#
# **Description**
#
#
#
#
# This notebook is the first step in the breast cancer classification project.
#
# This notebook downloads the Breast Cancer Wisconsin (Diagnostic) dataset from the UCI Machine Learning Repository via Kaggle, performs basic inspection, and saves a cleaned version for further analysis.
#
# - Source: [UCI ML Repository](https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+(Diagnostic))
# - Format: CSV
# - Samples: 569
# - Features: 30 numeric features + ID + diagnosis

# %% [markdown]
# ## Setup & Imports

# %%
# Install KaggleHub
# !pip install -q kagglehub

# %%
import pandas as pd
import numpy as np

import os
import kagglehub
import shutil

# %% [markdown]
# ## Create Project Directory

# %%
# Define project folder in Drive
TARGET_DIR = r"C:\Users\yasmine\Documents\Portfolio\DataSciencePortfolio\Projects\Breast-Cancer\data\raw"

# Create the directory if it doesn't exist
os.makedirs(TARGET_DIR, exist_ok=True)
print("Saving dataset to:", TARGET_DIR)
# Out:
# Saving dataset to: C:\Users\yasmine\Documents\Portfolio\DataSciencePortfolio\Projects\Breast-Cancer\data\raw

# %% [markdown]
# ## Download Dataset from Kaggle

# %%
DATASET = "wasiqaliyasir/breast-cancer-dataset"

# Download the dataset
dataset_path = kagglehub.dataset_download(DATASET)
print("Dataset downloaded to:", dataset_path)
# Out:
# Dataset downloaded to: C:\Users\yasmine\.cache\kagglehub\datasets\wasiqaliyasir\breast-cancer-dataset\versions\1

# %% [markdown]
# ## Save Dataset to Project Folder

# %%
for filename in os.listdir(dataset_path):
    src = os.path.join(dataset_path, filename)
    dst = os.path.join(TARGET_DIR, filename)
    if os.path.isfile(src):
        shutil.copy(src, dst)

print("Dataset saved to Drive at:", TARGET_DIR)
# Out:
# Dataset saved to Drive at: C:\Users\yasmine\Documents\Portfolio\DataSciencePortfolio\Projects\Breast-Cancer\data\raw

# %% [markdown]
# ## Preview the Data

# %%
csv_path = os.path.join(TARGET_DIR, "Breast_cancer_dataset.csv")
df = pd.read_csv(csv_path)


df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]
